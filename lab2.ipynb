# %% [markdown]
# # lab 2

# %%
import pandas as pd 
import warnings
warnings.simplefilter('ignore')

df = pd.read_csv('s3://ia340-2025-schunk-7569804/Border_Crossing_Entry_Data (1).csv') 
df.head()
# Out:
#       Port Name      State  Port Code            Border      Date  \
# 0       Jackman      Maine        104  US-Canada Border  Jan 2024
# 1      Porthill      Idaho       3308  US-Canada Border  Apr 2024
# 2      San Luis    Arizona       2608  US-Mexico Border  Apr 2024
# 3  Willow Creek    Montana       3325  US-Canada Border  Jan 2024
# 4       Warroad  Minnesota       3423  US-Canada Border  Jan 2024
#
#                        Measure  Value  Latitude  Longitude  \
# 0                       Trucks   6556    45.806    -70.397
# 1                       Trucks     98    49.000   -116.499
# 2                        Buses     10    32.485   -114.782
# 3                  Pedestrians      2    49.000   -109.731
# 4  Personal Vehicle Passengers   9266    48.999    -95.377
#
#                            Point
# 0   POINT (-70.396722 45.805661)
# 1   POINT (-116.49925 48.999861)
# 2    POINT (-114.7822222 32.485)
# 3  POINT (-109.731333 48.999972)
# 4      POINT (-95.376555 48.999)

# %% [markdown]
# ## A. View the Data

# %% [markdown]
# ## description
#     this data set has 403083 rows and 10 columns. The data is sorted by the name of the port, the state they entered, which border they crossed, the date they crossed, what measure of transportation they used, the value, and the latitude and longitude of their point they where at.

# %%
df.shape
# Out:
# (403083, 10)

# %%
df['Measure']
# Out:
# 0                              Trucks
# 1                              Trucks
# 2                               Buses
# 3                         Pedestrians
# 4         Personal Vehicle Passengers
#                      ...
# 403078         Truck Containers Empty
# 403079        Truck Containers Loaded
# 403080    Personal Vehicle Passengers
# 403081          Rail Containers Empty
# 403082                    Pedestrians
# Name: Measure, Length: 403083, dtype: object

# %%
df.sort_values(by='State')
# Out:
#                     Port Name       State  Port Code            Border  \
# 330186                  Alcan      Alaska       3104  US-Canada Border
# 175019              Ketchikan      Alaska       3102  US-Canada Border
# 175003                Skagway      Alaska       3103  US-Canada Border
# 74365                 Skagway      Alaska       3103  US-Canada Border
# 174993                  Alcan      Alaska       3104  US-Canada Border
# ...                       ...         ...        ...               ...
# 274007           Port Angeles  Washington       3007  US-Canada Border
# 401721  Chief Mountain Mt Poe         NaN       3315  US-Canada Border
# 401871  Chief Mountain Mt Poe         NaN       3315  US-Canada Border
# 402473  Chief Mountain Mt Poe         NaN       3315  US-Canada Border
# 402476  Chief Mountain Mt Poe         NaN       3315  US-Canada Border
#
#             Date                      Measure  Value  Latitude  Longitude  \
# ...

# %%
df[0:5]
# Out:
#       Port Name      State  Port Code            Border      Date  \
# 0       Jackman      Maine        104  US-Canada Border  Jan 2024
# 1      Porthill      Idaho       3308  US-Canada Border  Apr 2024
# 2      San Luis    Arizona       2608  US-Mexico Border  Apr 2024
# 3  Willow Creek    Montana       3325  US-Canada Border  Jan 2024
# 4       Warroad  Minnesota       3423  US-Canada Border  Jan 2024
#
#                        Measure  Value  Latitude  Longitude  \
# 0                       Trucks   6556    45.806    -70.397
# 1                       Trucks     98    49.000   -116.499
# 2                        Buses     10    32.485   -114.782
# 3                  Pedestrians      2    49.000   -109.731
# 4  Personal Vehicle Passengers   9266    48.999    -95.377
#
#                            Point
# 0   POINT (-70.396722 45.805661)
# 1   POINT (-116.49925 48.999861)
# 2    POINT (-114.7822222 32.485)
# 3  POINT (-109.731333 48.999972)
# 4      POINT (-95.376555 48.999)

# %%
df[df['Measure']=="Trucks"]
# Out:
#                      Port Name       State  Port Code            Border  \
# 0                      Jackman       Maine        104  US-Canada Border
# 1                     Porthill       Idaho       3308  US-Canada Border
# 7                      Warroad   Minnesota       3423  US-Canada Border
# 8                    Wildhorse     Montana       3323  US-Canada Border
# 27              Fort Fairfield       Maine        107  US-Canada Border
# ...                        ...         ...        ...               ...
# 403035                 Nogales     Arizona       2604  US-Mexico Border
# 403041  Champlain Rouses Point    New York        712  US-Canada Border
# 403052               Pinecreek   Minnesota       3425  US-Canada Border
# 403068              Port Huron    Michigan       3802  US-Canada Border
# 403073                   Sumas  Washington       3009  US-Canada Border
#
#             Date Measure  Value  Latitude  Longitude  \
# ...

# %% [markdown]
# ## B. Explore and Clean Data

# %% [markdown]
# ## Description
#     I renamed the "measure" column to "transport". I found 16 missing values and i dropped them using the dropna() function

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 403083 entries, 0 to 403082
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Port Name  403083 non-null  object
#  1   State      403079 non-null  object
#  2   Port Code  403083 non-null  int64
#  3   Border     403083 non-null  object
#  4   Date       403083 non-null  object
#  5   Measure    403083 non-null  object
#  6   Value      403083 non-null  int64
#  7   Latitude   403079 non-null  float64
#  8   Longitude  403079 non-null  float64
#  9   Point      403079 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 30.8+ MB

# %%
df = df.rename(columns={"Measure": "Transport"})
df.head()
# Out:
#       Port Name      State  Port Code            Border      Date  \
# 0       Jackman      Maine        104  US-Canada Border  Jan 2024
# 1      Porthill      Idaho       3308  US-Canada Border  Apr 2024
# 2      San Luis    Arizona       2608  US-Mexico Border  Apr 2024
# 3  Willow Creek    Montana       3325  US-Canada Border  Jan 2024
# 4       Warroad  Minnesota       3423  US-Canada Border  Jan 2024
#
#                      Transport  Value  Latitude  Longitude  \
# 0                       Trucks   6556    45.806    -70.397
# 1                       Trucks     98    49.000   -116.499
# 2                        Buses     10    32.485   -114.782
# 3                  Pedestrians      2    49.000   -109.731
# 4  Personal Vehicle Passengers   9266    48.999    -95.377
#
#                            Point
# 0   POINT (-70.396722 45.805661)
# 1   POINT (-116.49925 48.999861)
# 2    POINT (-114.7822222 32.485)
# 3  POINT (-109.731333 48.999972)
# 4      POINT (-95.376555 48.999)

# %%
df.isnull().sum()
# Out:
# Port Name    0
# State        4
# Port Code    0
# Border       0
# Date         0
# Transport    0
# Value        0
# Latitude     4
# Longitude    4
# Point        4
# dtype: int64

# %%
df = df.dropna() 
df.isnull().sum()
# Out:
# Port Name    0
# State        0
# Port Code    0
# Border       0
# Date         0
# Transport    0
# Value        0
# Latitude     0
# Longitude    0
# Point        0
# dtype: int64

# %%
df.describe()
# Out:
#            Port Code         Value       Latitude      Longitude
# count  403079.000000  4.030790e+05  403079.000000  403079.000000
# mean     2445.390139  2.903962e+04      43.961375     -99.709766
# std      1204.478369  1.494387e+05       8.154120      18.260592
# min       101.000000  0.000000e+00      25.952000    -141.001000
# 25%      2304.000000  0.000000e+00      42.999000    -114.728000
# 50%      3012.000000  1.520000e+02      48.122000    -101.628000
# 75%      3401.000000  3.078500e+03      49.000000     -84.361000
# max      3814.000000  4.447374e+06      62.615000     -66.980000

# %%
df = df[['State' , 'Border' , 'Date' , 'Transport' , 'Value']]
df.head()
# Out:
#        State            Border      Date                    Transport  Value
# 0      Maine  US-Canada Border  Jan 2024                       Trucks   6556
# 1      Idaho  US-Canada Border  Apr 2024                       Trucks     98
# 2    Arizona  US-Mexico Border  Apr 2024                        Buses     10
# 3    Montana  US-Canada Border  Jan 2024                  Pedestrians      2
# 4  Minnesota  US-Canada Border  Jan 2024  Personal Vehicle Passengers   9266

# %%
df = df[['Transport']] 
df.head()
# Out:
#                      Transport
# 0                       Trucks
# 1                       Trucks
# 2                        Buses
# 3                  Pedestrians
# 4  Personal Vehicle Passengers

# %%
df['Transport']
# Out:
# 0                              Trucks
# 1                              Trucks
# 2                               Buses
# 3                         Pedestrians
# 4         Personal Vehicle Passengers
#                      ...
# 403078         Truck Containers Empty
# 403079        Truck Containers Loaded
# 403080    Personal Vehicle Passengers
# 403081          Rail Containers Empty
# 403082                    Pedestrians
# Name: Transport, Length: 403079, dtype: object

# %%
df[5:10]
# Out:
#                      Transport
# 5            Personal Vehicles
# 6  Personal Vehicle Passengers
# 7                       Trucks
# 8                       Trucks
# 9  Personal Vehicle Passengers

# %%
df[df['Transport'] == 'Trucks']
# Out:
#        Transport
# 0         Trucks
# 1         Trucks
# 7         Trucks
# 8         Trucks
# 27        Trucks
# ...          ...
# 403035    Trucks
# 403041    Trucks
# 403052    Trucks
# 403068    Trucks
# 403073    Trucks
#
# [37181 rows x 1 columns]

# %%
sum_cases_by_date = df.groupby('State')['Value'].sum()
sum_cases_by_date.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sum_cases_by_date = df.groupby('State')['Value'].sum()
#       2 sum_cases_by_date.head()
#
# File ~/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages/pandas/core/frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
#    9191     obj=self,
#    9192     keys=by,
#    9193     axis=axis,
#    9194     level=level,
#    9195     as_index=as_index,
#    9196     sort=sort,
#    9197     group_keys=group_keys,
#    9198     observed=observed,
#    9199     dropna=dropna,
#    9200 )
#
# ...

# %%
value_by_country = df.groupby('State')['Value'].sum() 
value_by_country.nlargest(10).plot.bar()

# %%
sum_Value_by_Date = df.groupby('Date')['Value'].sum() 
sum_value_by_date.head()

# %%
df['Date'] = pd.to_datetime(df'['Date'])

# %%
df = df.sort_values('Date')

# %%
df.plot(x='Date' , y='Value' , kind='line' , legand=False , linewidth=2 , title="Trend over Time"
